# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import lsst.afw.cameraGeom.utils as cgUtils

from lsst.obs.ztf import ZTF

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib')

# %%
ztf = ZTF()

# %%
disp = afwDisplay.Display(1)
if True:
    mos = cgUtils.showCamera(ztf, overlay=True, display=disp)
else:
    mos = cgUtils.showCcd(ztf[1], overlay=True, display=disp)

# %%
cgUtils.plotFocalPlane(ztf)
#plt.axhline(0, ls=':', color='black')
#plt.axvline(0, ls=':', color='black')
plt.gcf().axes[0].set_aspect('equal');
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
import lsst.daf.persistence as dafPersist

butler = dafPersist.Butler("/Users/rhl/LSST/Data/comCam/repo")

# %%
butler.queryMetadata("src")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1bd9a3e5d859> in <module>()
# ----> 1 butler.queryMetadata("src")
#
# /Users/lsst/products/DarwinX86/miniconda/latest/envs/lsst-13_0/opt/lsst/daf_persistence/python/lsst/daf/persistence/butler.pyc in queryMetadata(self, datasetType, format, dataId, **rest)
#     543
#     544         if format is None:
# --> 545             format = (key,)
#     546         else:
#     547             format = sequencify(format)
#
# NameError: global name 'key' is not defined
